# %%
import pandas as pd
import numpy as np


url = ("https://raw.githubusercontent.com/sreekx007/Subsea-S-Lay-ILS-Machine-Learning/main/"
"Studies/Exploratory%20Analyses/ILS_parametric_study_EDA_dataset.csv")

df = pd.read_csv(url)
df.shape
df.columns
df
# Out:
# 0     ILS-001
# 1     ILS-002
# 2     ILS-003
# 3     ILS-004
# 4     ILS-005
#        ...
# 58    ILS-059
# 59    ILS-060
# 60    ILS-061
# 61    ILS-062
# 62    ILS-063
# Name: record_id, Length: 63, dtype: object
